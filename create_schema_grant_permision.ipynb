# %%
# %sql
CREATE CATALOG IF NOT EXISTS proyecto;

CREATE SCHEMA IF NOT EXISTS proyecto.raw;
CREATE SCHEMA IF NOT EXISTS proyecto.bronze;
CREATE SCHEMA IF NOT EXISTS proyecto.silver;
CREATE SCHEMA IF NOT EXISTS proyecto.golden;

# %%
# %sql
CREATE EXTERNAL VOLUME IF NOT EXISTS proyecto.raw.raw_data
LOCATION 'abfss://raw@adlscshm.dfs.core.windows.net/instacart/';

# %%
# %sql
SELECT current_user();

# %%
# %sql
ALTER CATALOG proyecto OWNER TO `tianoh84@hotmail.com`;
ALTER SCHEMA  proyecto.bronze OWNER TO `tianoh84@hotmail.com`;
ALTER SCHEMA  proyecto.silver OWNER TO `tianoh84@hotmail.com`;
ALTER SCHEMA  proyecto.golden   OWNER TO `tianoh84@hotmail.com`;

# %%
# %sql
SHOW EXTERNAL LOCATIONS;

# %%
# %sql 
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION bronze TO `tianoh84@hotmail.com`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION silver TO `tianoh84@hotmail.com`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION golden   TO `tianoh84@hotmail.com`;
