# %%
# %sql
CREATE CATALOG IF NOT EXISTS proyecto;

CREATE SCHEMA IF NOT EXISTS proyecto.raw;
CREATE SCHEMA IF NOT EXISTS proyecto.bronze;
CREATE SCHEMA IF NOT EXISTS proyecto.silver;
CREATE SCHEMA IF NOT EXISTS proyecto.golden;

# %%
# %sql
create EXTERNAL volume proyecto.raw.raw_data
location 'abfss://raw@adlscshm.dfs.core.windows.net/'

# %%
# %sql
SHOW STORAGE CREDENTIALS;

# %%
# %sql
drop TABLE IF EXISTS proyecto.bronze.aisles;
drop TABLE IF EXISTS proyecto.bronze.departments;
drop TABLE IF EXISTS proyecto.bronze.order_products;
drop TABLE IF EXISTS proyecto.bronze.orders;
drop TABLE IF EXISTS proyecto.bronze.products;
